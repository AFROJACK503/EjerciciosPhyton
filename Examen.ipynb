# %%
#Mi nombre (Kelvin Armando)
#Mi apellido (Centeno Garcia)
#Mi Fruta Favorita (Melon)



mi_nombre ="""

k    k
k  k
k k
kk
k k
k  k
k   k

 ggg
g   g 
g
ggggg
g   g
g   g
 ggg"""

print (mi_nombre)


fruta_favorita ="""

m    m
mm  mm
mm  mm
m  m m
m    m
m    m
m    m"""

print (fruta_favorita)


melon="""

ooooo
o   o
o   o
o   o
o   o
o   o
ooooo"""

print (melon)
# Out:
# k    k
# k  k
# k k
# kk
# k k
# k  k
# k   k
#
#  ggg
# g   g
# g
# ggggg
# g   g
# g   g
#  ggg
#
#
# m    m
# mm  mm
# mm  mm
# m  m m
# m    m
# m    m
# m    m
#
#
# ooooo
# o   o
# o   o
# o   o
# o   o
# o   o
# ooooo

# %%
#1precio
lovely_loveseat_description = """\nLovely Loveseat 
Tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep. 
Red or white"""

print (lovely_loveseat_description)

lovely_loveseat_price=254.00
print (lovely_loveseat_price)







#2precio
styling_settee_description ="""\nStylish Settee. 
Faux leather on birch. 
29.50 inches high x 54.75 inches wide x 28 inches deep. 
Black"""

print (styling_settee_description)

style_settee_price=180.50
print (style_settee_price)





#3precio
luxury_lamp_description ="""\nLuxurious Lamp. 
Glass and iron. 
36 inches tall. 
Brown with cream shade"""

print(luxury_lamp_description)





#4ejercicio
luxury_lamp_price=52.15
print(luxury_lamp_price)





#5ejercicio
sales_tax=0.088

print(round(sales_tax,2))



#8ejercicio
#customer_one_total=0
#print(customer_one_total)

#9ejercicio
customer_one_itemization="""descripcion de mi tienda"""
print(customer_one_itemization)

#10 12ejercicio
customer_one_total = lovely_loveseat_price + luxury_lamp_price
print(customer_one_total)

#11ejercicio
customer_one_itemization = luxury_lamp_description

print (customer_one_itemization)

#14ejercicio
customer_one_tax = customer_one_total * sales_tax

print (customer_one_tax)

#15
customer_one_total + sales_tax

#16 #17

print ("Customer One Items")
print (customer_one_itemization)

#18 #19
print ("Customer One Total")
print (customer_one_total)

#20 #21 #22 #23
customer_two_total=0
customer_two_itemization=customer_two_total
customer_two_itemization="""description of stylish sofa"""
print (customer_two_total)

#24
discount=luxury_lamp_price-0.2
print(round(discount))
discount2=lovely_loveseat_price-0.15
print(round(discount2))

#25
Lovely_LoveSeat="""descripcion1"""
Luxurious_Lamp="""descripcion2"""

#26
customer_two_tax=customer_two_total*sales_tax
print (customer_two_tax)

#27


print (customer_Two_itemization)
# Out:
# Lovely Loveseat
# Tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep.
# Red or white
# 254.0
#
# Stylish Settee.
# Faux leather on birch.
# 29.50 inches high x 54.75 inches wide x 28 inches deep.
# Black
# 180.5
#
# Luxurious Lamp.
# Glass and iron.
# 36 inches tall.
# Brown with cream shade
# 52.15
# 0.09
# descripcion de mi tienda
# 306.15
#
# Luxurious Lamp.
# Glass and iron.
# 36 inches tall.
# Brown with cream shade
# 26.941199999999995
# Customer One Items
#
# Luxurious Lamp.
# Glass and iron.
# 36 inches tall.
# Brown with cream shade
# Customer One Total
# 306.15
# 0
# 52
# 254
# 0.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 116>()
#     111 print (customer_two_tax)
#     113 #27
# --> 116 print (customer_Two_itemization)
#
# NameError: name 'customer_Two_itemization' is not defined
